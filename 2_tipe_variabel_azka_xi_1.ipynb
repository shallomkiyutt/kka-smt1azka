# %% [markdown]
# <a href="https://colab.research.google.com/github/shallomkiyutt/kka-smt1azka/blob/main/2_tipe_variabel_azka_xi_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama: Azka shivlya alva shallom
# Kelas:XI.1
# No.absen:29

# %% [markdown]
# #Konsep Dasar

# %%
email_user_1= "@azkashivlyaalvashallom.2025@gmail.com"
print(email_user_1)
# Out:
# @azkashivlyaalvashallom.2025@gmail.com

# %%
sabun_lifebuoy=15000

print (sabun_lifebuoy)
# Out:
# 15000

# %%
print(sabun_lifebuoy*5)
# Out:
# 75000

# %% [markdown]
# #Peraturan penulisan variabel

# %%
#penulisan variabel hanya boleh menggukan huruf,angka dan underscore
#tidak boleh menggunakan spasi
nama siswa = "afa"

print (nama siswa
# Out:
#   File "/tmp/ipython-input-442903354.py", line 3
#     nama siswa = "afa"
#          ^
# SyntaxError: invalid syntax

# %%
#tidak boleh diawali dengan angka

1_nama_siswa="afa"
print(1_nama_siswa)
# Out:
#   File "/tmp/ipython-input-2745948412.py", line 3
#     1_nama_siswa="afa"
#      ^
# SyntaxError: invalid decimal literal

# %%
#penulisan variabel itu case sensitive/sensitif capslock
nama_siswa_1 = "afa"

print(Nama_siswa_1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1716074385.py in <cell line: 0>()
#       2 nama_siswa_1 = "afa"
#       3
# ----> 4 print(Nama_siswa_1)
#
# NameError: name 'Nama_siswa_1' is not defined

# %%
#dilarang menggukan kata kunci di bahsa python
prin="shello"

print(prin)
# Out:
# shello

# %%
end="shello"

print(end)
# Out:
# shello

# %%
#Deskriptif
_="shello"

print(_)
# Out:
# shello

# %%
#tidak boleh pakai kata kunci python
#kalau error,harus disconnect dulu
#print = "shello"

#print(print)

# %% [markdown]
# #Assignment

# %% [markdown]
# ##Single assignment

# %%
nama_siswa_2="tun"
nama_siswa_3="shello"
print(nama_siswa_2)
print(nama_siswa_3)
# Out:
# tun
# shello

# %% [markdown]
# ##Multiple assignment

# %%
nama_siswa_4,nama_siswa_5="tun","shello"

print(nama_siswa_4)
print(nama_siswa_5)
# Out:
# tun
# shello

# %% [markdown]
# ##assign ke banyak variabel sekaligus

# %%
nilai_shello=nilai_tun=100

print(nilai_shello)
print(nilai_tun)
# Out:
# 100
# 100

# %% [markdown]
# ##perubahan nilai variabel

# %%
nilai_shello=95
print(nilai_shello)
# Out:
# 95

# %% [markdown]
# #Aritmatika

# %%
print("5000*3")
# Out:
# 5000*3

# %%
#operand tanpa disimpan dalam variabel
print (5000*3)
# Out:
# 15000

# %%
#simpan operand ke dalam variabel
harga_kojek =6000
banyak_porsi=3

print(harga_kojek*banyak_porsi)
# Out:
# 18000

# %%
#simpan hasil operasi ke dalam variabel
harga_total_kojek=3000*3

print (harga_total_kojek)
# Out:
# 9000

# %%
#simpan nilai operand dan hasil operasi ke dalam variabel
harga_cilok=10000
jumlah_porsi_cilok=5
harga_total_cilok=harga_cilok*jumlah_porsi_cilok

print(harga_total_cilok)
# Out:
# 50000

# %%
uang_yang_diterima=100000
uang_kembalian=uang_yang_diterima-harga_total_cilok

print(uang_kembalian)
# Out:
# 50000

# %% [markdown]
# #soal
# satu kardus berisi 24 botol minum.jika ada 3 kardus,berapa jumlah botol?

# %%
print (24*3)
# Out:
# 72

# %%
total_jumlah_botol=24*3
print (total_jumlah_botol)
# Out:
# 72

# %%
banyak_botol_per_kardus=24
jumlah_kardus=3
print (banyak_botol_per_kardus*jumlah_kardus)
# Out:
# 72

# %%
banyak_botol_per_kardus=24
jumlah_kardus=3
total_jumlah_botol=banyak_botol_per_kardus*jumlah_kardus
print(total_jumlah_botol)
# Out:
# 72

# %% [markdown]
# #Tipe Variabel

# %%
usia=65

type(usia)
# Out:
# int

# %%
berat_telur=2.5
type(berat_telur)
# Out:
# float

# %%
nama="shinta"
type(nama)
# Out:
# str

# %%
remidi=False
type (remidi)
# Out:
# bool

# %%
remidi=True
type(remidi)
# Out:
# bool

# %%
koordinat_bintang=-1.5
type (koordinat_bintang)
# Out:
# float

# %%
koordinat_titik=-8
type(koordinat_titik)
# Out:
# int

# %% [markdown]
# #input

# %%
panjang=10
lebar=5
luas=panjang*lebar

print(luas)
# Out:
# 50

# %%
input()
# Out:
# 10
# '10'

# %%
panjang=input()
# Out:
# 10

# %%
print(panjang)
# Out:
# 10

# %%
lebar=input()
# Out:
# 5

# %%
print(lebar)
# Out:
# 5

# %%
#type data masih string dan harus di convert ke integer/float
luas=panjang*lebar
print(luas)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2828913838.py in <cell line: 0>()
#       1 #type data masih string dan harus di convert ke integer/float
# ----> 2 luas=panjang*lebar
#       3 print(luas)
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
type(panjang)
# Out:
# str

# %%
type(lebar)
# Out:
# str

# %%
panjang=int(panjang)

# %%
lebar=int (panjang)

# %%
type(panjang)
# Out:
# int

# %%
panjang_1=int(input("masukkan panjang persegi:"))
# Out:
# masukkan panjang persegi:10

# %%
panjang_2=int(input("masukkan panjang persegi:"))
lebar_2=int(input("masukkan lebar persegi:"))

luas_2=panjang_2*lebar_2
print(f"luas persegi panjang adalah {luas_2}cm^2")
# Out:
# masukkan panjang persegi:4
# masukkan lebar persegi:10
# luas persegi panjang adalah 40cm^2

# %% [markdown]
# #tugas

# %%
panjang=float(input("masukkan panjang(dalam cm):"))
lebar=float(input("masukkan lebar(dalam cm):"))
tinggi=float(input("masukkan tinggi(dalam cm):"))
# Out:
# masukkan panjang(dalam cm):10
# masukkan lebar(dalam cm):5
# masukkan tinggi(dalam cm):4

# %%
volume=panjang*lebar*tinggi

# %%
print(f"volume balok adalah:{volume}cm³")
# Out:
# volume balok adalah:200.0cm³

# %%
panjang=float(input("masukkan panjang (dalam cm):"))
lebar=float(input("masukkan lebar(dalam cm):"))
tinggi=float(input("masukkan tinggi(dalam cm):"))

volume(f"volume balok adalah:{volume}cm³")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3527950168.py in <cell line: 0>()
# ----> 1 panjang=float(input("masukkan panjang (dalam cm):"))
#       2 lebar=float(input("masukkan lebar(dalam cm):"))
#       3 tinggi=float(input("masukkan tinggi(dalam cm):"))
#       4
#       5 volume(f"volume balok adalah:{volume}cm³")
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# #Konversi tipe data

# %%
a=3
print(a)
type(a)
# Out:
# 3
# int

# %%
a=float(a)
print(a)
type (a)
# Out:
# 3.0
# float

# %%
a = str(a)
print(a)
type(a)
# Out:
# 3.0
# str

# %%
a=bool(a)
print(a)
type(a)
# Out:
# True
# bool

# %%
b="cicak"
print(b)

b=bool(b)
print(b)
# Out:
# cicak
# True

# %%
c=""
print(c)

c=bool(c)
print(c)
# Out:
# False

# %%
d = False
print(d)
type(d)
# Out:
# False
# bool

# %%
e="false"
print(e)
type(e)
# Out:
# false
# str

# %% [markdown]
# #Operator Perbanding

# %%
print(8<5)
# Out:
# False

# %%
print(8>5)
# Out:
# True

# %%
print(9>=9)
# Out:
# True

# %%
print(8==5)
# Out:
# False

# %%
print(8==8)
# Out:
# True

# %%
print(1!=1)
# Out:
# False

# %%
a=10
b=20
c=30
print(a>c)
# Out:
# False

# %%
print(a>30)
# Out:
# False

# %%
nilai_kka=75
kkm_kka=80
print(nilai_kka>kkm_kka)
# Out:
# False

# %% [markdown]
# #Operator logika

# %%
print(8>7 and 5<6)
# Out:
# True

# %%
print(8>7 or 5<6)
# Out:
# True

# %%
print(not(8>7 or 5>6))
# Out:
# False

# %%
print(not (8>=9 or 9!=8))
# Out:
# False

# %%
iq_min=125
tinggi_min=165

print(125 >= iq_min and 170 >= tinggi_min)
# Out:
# True

# %%
iq_afa = 125
tinggi_afa = 170

print(iq_afa >= iq_min and tinggi_afa >= tinggi_min)
# Out:
# True

# %%
tinggi_min = 165
berat_badan_min = 50
umur_max = 25

tinggi_farel = 170
berat_badan_farel = 55
umur_farel = 23

print(tinggi_farel >= tinggi_min and berat_badan_farel >= berat_badan_min and umur_farel <= umur_max)
# Out:
# True
